# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_absolute_error, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %%
#Read in Data
rec = pd.read_csv('data/recidivism_clean.csv')

# %%
#Drop these for predictions prior to prison release
rec = rec.drop(['Supervision_Risk_Score_First', 'Supervision_Level_First', 'Violations_ElectronicMonitoring', 'Violations_FailToReport', 
                'Violations_FailToReport', 'Violations_MoveWithoutPermission', 'Delinquency_Reports', 'Program_Attendances', 
                'Program_UnexcusedAbsences','Residence_Changes', 'DrugTests_THC_Positive', 'DrugTests_Cocaine_Positive', 
                'DrugTests_Meth_Positive', 'DrugTests_Other_Positive', 'Employment_Exempt', 'employed'], axis=1)

# %%
# Convert strings/objects to categories
rec[rec.select_dtypes(['object']).columns] = rec.select_dtypes(['object']).astype('category')

#rec_train was the data provided to train the model and rec_val represents the evaluation data
rec_train = rec[rec['Training_Sample'] == 1]
rec_val = rec[rec['Training_Sample'] == 0]

#Get Number of Observations for training and  validation set
n_train = rec_train.shape[0]
n_val = rec_val.shape[0]

# %%
#split the data used for cross validation as rec_train and data for final evaluation as rec_test
#Also drop the columns I do not want, and capturing the variable of interest in the y variable

X = rec_train.drop(['Recidivism_Arrest_Year1', 'Recidivism_Arrest_Year2', 'Recidivism_Arrest_Year3', 'Recidivism_Within_3years', 'Training_Sample', 'ID', 'Race'], axis=1)
y = rec_train['Recidivism_Within_3years']

X_test = rec_val.drop(['Recidivism_Arrest_Year1', 'Recidivism_Arrest_Year2', 'Recidivism_Arrest_Year3', 'Recidivism_Within_3years', 'Training_Sample', 'ID', 'Race'], axis=1)
y_test = rec_val['Recidivism_Within_3years']

# %%
#Define Bayesian Optimization Search Space

space = {
    'num_leaves': 5, #hp.quniform('num_leaves', 2, 100, 1),
    'bagging_fraction': hp.uniform('bagging_fraction', 0.75, 1),
    'feature_fraction': 0.9710810081829547, #hp.uniform('feature_fraction', 0.25, 1),
    'learning_rate': 0.1554172850388652, #hp.loguniform('learning_rate', -3, -1),    
    'reg_alpha': hp.uniform('reg_alpha', 0, 0.25),
    'reg_lambda': hp.uniform('reg_lambda', 0, 0.25),
    'max_depth': 8, # hp.quniform('max_depth', 1, 10, 1),
}

# %%
#Create function to run cross validation while searching for optimal hyper-parameters
def objective(params):
    
    params = {
        'num_leaves': int(params['num_leaves']),
        'max_depth': int(params['max_depth']),
        'bagging_fraction': float(params['bagging_fraction']),
        'feature_fraction': float(params['feature_fraction']),
        'learning_rate': float(params['learning_rate']),
        'reg_alpha': float(params['reg_alpha']),
        'reg_lambda': float(params['reg_lambda']), 
        'n_jobs' : -1,
        'boosting_type': 'gbdt'
    }

    model = lgb.LGBMClassifier(**params, random_state=1994)
    kf = KFold(n_splits=6, random_state=1994, shuffle=True)
    score = np.mean(cross_val_score(model, X, y, cv=kf, scoring='neg_brier_score'))
    
    return {'loss': -score, 'status': STATUS_OK}

# %%
#Use hyperopt fmin function to find optimal parameters
trials = Trials()
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=200, trials=trials)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8430133603271126, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8430133603271126
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8430133603271126, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8430133603271126
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8430133603271126, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8430133603271126
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8430133603271126, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8430133603271126
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8430133603271126, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8430133603271126
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8430133603271126, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8430133603271126
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8639848868390821, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8639848868390821
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8639848868390821, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8639848868390821
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8639848868390821, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8639848868390821
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8639848868390821, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8639848868390821
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8639848868390821, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8639848868390821
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8639848868390821, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8639848868390821
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8090772177530416, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8090772177530416
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8090772177530416, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8090772177530416
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8090772177530416, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8090772177530416
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8090772177530416, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8090772177530416
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8090772177530416, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8090772177530416
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8090772177530416, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8090772177530416
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7681668062938461, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7681668062938461
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7681668062938461, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7681668062938461
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7681668062938461, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7681668062938461
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7681668062938461, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7681668062938461
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7681668062938461, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7681668062938461
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7681668062938461, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7681668062938461
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8560470849855348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8560470849855348
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8560470849855348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8560470849855348
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8560470849855348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8560470849855348
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8560470849855348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8560470849855348
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8560470849855348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8560470849855348
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8560470849855348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8560470849855348
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9827576206304482, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9827576206304482
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9827576206304482, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9827576206304482
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9827576206304482, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9827576206304482
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9827576206304482, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9827576206304482
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9827576206304482, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9827576206304482
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9827576206304482, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9827576206304482
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8643038186463248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8643038186463248
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8643038186463248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8643038186463248
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8643038186463248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8643038186463248
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8643038186463248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8643038186463248
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8643038186463248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8643038186463248
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8643038186463248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8643038186463248
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9273583874916909, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9273583874916909
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9273583874916909, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9273583874916909
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9273583874916909, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9273583874916909
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9273583874916909, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9273583874916909
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9273583874916909, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9273583874916909
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9273583874916909, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9273583874916909
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7841156203540844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7841156203540844
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7841156203540844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7841156203540844
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7841156203540844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7841156203540844
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7841156203540844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7841156203540844
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7841156203540844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7841156203540844
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7841156203540844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7841156203540844
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9635924422938712, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9635924422938712
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9635924422938712, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9635924422938712
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9635924422938712, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9635924422938712
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9635924422938712, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9635924422938712
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9635924422938712, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9635924422938712
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9635924422938712, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9635924422938712
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.935476754706567, subsample=1.0 will be ignored. Current value: bagging_fraction=0.935476754706567
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.935476754706567, subsample=1.0 will be ignored. Current value: bagging_fraction=0.935476754706567
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.935476754706567, subsample=1.0 will be ignored. Current value: bagging_fraction=0.935476754706567
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.935476754706567, subsample=1.0 will be ignored. Current value: bagging_fraction=0.935476754706567
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.935476754706567, subsample=1.0 will be ignored. Current value: bagging_fraction=0.935476754706567
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.935476754706567, subsample=1.0 will be ignored. Current value: bagging_fraction=0.935476754706567
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9102358370440746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9102358370440746
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9102358370440746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9102358370440746
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9102358370440746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9102358370440746
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9102358370440746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9102358370440746
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9102358370440746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9102358370440746
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9102358370440746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9102358370440746
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9667890322239518, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9667890322239518
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9667890322239518, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9667890322239518
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9667890322239518, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9667890322239518
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9667890322239518, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9667890322239518
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9667890322239518, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9667890322239518
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9667890322239518, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9667890322239518
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8653776351398634, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8653776351398634
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8653776351398634, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8653776351398634
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8653776351398634, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8653776351398634
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8653776351398634, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8653776351398634
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8653776351398634, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8653776351398634
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8653776351398634, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8653776351398634
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9360576002488533, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9360576002488533
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9360576002488533, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9360576002488533
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9360576002488533, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9360576002488533
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9360576002488533, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9360576002488533
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9360576002488533, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9360576002488533
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9360576002488533, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9360576002488533
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022442053748372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022442053748372
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022442053748372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022442053748372
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022442053748372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022442053748372
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022442053748372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022442053748372
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022442053748372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022442053748372
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022442053748372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022442053748372
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9902051471167224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9902051471167224
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9902051471167224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9902051471167224
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9902051471167224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9902051471167224
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9902051471167224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9902051471167224
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9902051471167224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9902051471167224
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9902051471167224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9902051471167224
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8795005872558368, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8795005872558368
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8795005872558368, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8795005872558368
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8795005872558368, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8795005872558368
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8795005872558368, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8795005872558368
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8795005872558368, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8795005872558368
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8795005872558368, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8795005872558368
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.946274945465052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.946274945465052
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.946274945465052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.946274945465052
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.946274945465052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.946274945465052
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.946274945465052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.946274945465052
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.946274945465052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.946274945465052
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.946274945465052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.946274945465052
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7849597283832292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7849597283832292
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7849597283832292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7849597283832292
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7849597283832292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7849597283832292
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7849597283832292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7849597283832292
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7849597283832292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7849597283832292
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7849597283832292, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7849597283832292
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8290430687674012, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8290430687674012
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8290430687674012, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8290430687674012
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8290430687674012, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8290430687674012
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8290430687674012, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8290430687674012
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8290430687674012, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8290430687674012
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8290430687674012, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8290430687674012
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022448524588902, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022448524588902
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022448524588902, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022448524588902
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022448524588902, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022448524588902
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022448524588902, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022448524588902
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022448524588902, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022448524588902
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9022448524588902, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9022448524588902
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9678285035688857, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9678285035688857
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9678285035688857, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9678285035688857
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9678285035688857, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9678285035688857
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9678285035688857, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9678285035688857
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9678285035688857, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9678285035688857
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9678285035688857, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9678285035688857
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8890490640914807, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8890490640914807
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8890490640914807, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8890490640914807
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8890490640914807, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8890490640914807
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8890490640914807, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8890490640914807
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8890490640914807, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8890490640914807
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8890490640914807, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8890490640914807
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9968207136464584, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9968207136464584
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9968207136464584, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9968207136464584
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9968207136464584, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9968207136464584
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9968207136464584, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9968207136464584
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9968207136464584, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9968207136464584
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9968207136464584, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9968207136464584
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8132174185029323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8132174185029323
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8132174185029323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8132174185029323
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8132174185029323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8132174185029323
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8132174185029323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8132174185029323
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8132174185029323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8132174185029323
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8132174185029323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8132174185029323
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9623520384334457, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9623520384334457
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9623520384334457, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9623520384334457
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9623520384334457, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9623520384334457
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# ...
# [LightGBM] [Warning] bagging_fraction is set=0.8248093066399403, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8248093066399403
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8248093066399403, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8248093066399403
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8248093066399403, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8248093066399403
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8248093066399403, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8248093066399403
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8248093066399403, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8248093066399403
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9524625855401654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9524625855401654
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9524625855401654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9524625855401654
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9524625855401654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9524625855401654
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9524625855401654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9524625855401654
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9524625855401654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9524625855401654
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9524625855401654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9524625855401654
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.999908012086452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.999908012086452
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.999908012086452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.999908012086452
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.999908012086452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.999908012086452
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.999908012086452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.999908012086452
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.999908012086452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.999908012086452
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.999908012086452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.999908012086452
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8096703345012075, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8096703345012075
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8096703345012075, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8096703345012075
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8096703345012075, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8096703345012075
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8096703345012075, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8096703345012075
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8096703345012075, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8096703345012075
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.8096703345012075, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8096703345012075
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9040965809936077, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9040965809936077
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9040965809936077, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9040965809936077
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9040965809936077, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9040965809936077
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9040965809936077, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9040965809936077
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9040965809936077, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9040965809936077
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9040965809936077, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9040965809936077
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.758209285216464, subsample=1.0 will be ignored. Current value: bagging_fraction=0.758209285216464
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.758209285216464, subsample=1.0 will be ignored. Current value: bagging_fraction=0.758209285216464
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.758209285216464, subsample=1.0 will be ignored. Current value: bagging_fraction=0.758209285216464
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.758209285216464, subsample=1.0 will be ignored. Current value: bagging_fraction=0.758209285216464
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.758209285216464, subsample=1.0 will be ignored. Current value: bagging_fraction=0.758209285216464
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.758209285216464, subsample=1.0 will be ignored. Current value: bagging_fraction=0.758209285216464
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7859689603011815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7859689603011815
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7859689603011815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7859689603011815
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7859689603011815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7859689603011815
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7859689603011815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7859689603011815
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7859689603011815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7859689603011815
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.7859689603011815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7859689603011815
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.841614052450778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.841614052450778
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.841614052450778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.841614052450778
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.841614052450778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.841614052450778
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.841614052450778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.841614052450778
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.841614052450778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.841614052450778
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.841614052450778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.841614052450778
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9136182486989707, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9136182486989707
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9136182486989707, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9136182486989707
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9136182486989707, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9136182486989707
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9136182486989707, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9136182486989707
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9136182486989707, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9136182486989707
# [LightGBM] [Warning] feature_fraction is set=0.9710810081829547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9710810081829547
# [LightGBM] [Warning] bagging_fraction is set=0.9136182486989707, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9136182486989707
# 100%|██████████| 200/200 [02:04<00:00,  1.61trial/s, best loss: 0.20243617660114033]

# %%
print(best)

#print('max_depth', best['max_depth'] + depth_start)
# Out:
# {'bagging_fraction': 0.7990114523775765, 'reg_alpha': 0.06766451909430012, 'reg_lambda': 0.19624464361828178}

# %%
#Bring in best hyperparameters from tuning
params = {
    'num_leaves': int(best['num_leaves']),
    'bagging_fraction': best['bagging_fraction'],
    'feature_fraction': best['feature_fraction'],
    'learning_rate': best['learning_rate'],
    'reg_alpha': best['reg_alpha'],
    'reg_lambda': best['reg_lambda'],
    'n_jobs' : -1,
    'max_depth': best['max_depth']
    }

#Fit model
model = lgb.LGBMClassifier(**params, random_state=1994)
model.fit(X,y)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8762706652098655, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8762706652098655
# [LightGBM] [Warning] bagging_fraction is set=0.33395516821065346, subsample=1.0 will be ignored. Current value: bagging_fraction=0.33395516821065346
# LGBMClassifier(bagging_fraction=0.33395516821065346,
#                feature_fraction=0.8762706652098655,
#                learning_rate=0.1505316107684715, max_depth=1, num_leaves=86,
#                random_state=1994, reg_alpha=0.3704714419072009,
#                reg_lambda=0.6388250407579474)

# %%
#Predict recidivism, print accuracy
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.7051357733175915

# %%
#Predict probability of recidivism
y_pred_prob = model.predict_proba(X_test)

#Extract probability of recidivism as predict_proba returns an array that has both probability of not recidivating and probability of recidivating
y_pred_prob = y_pred_prob[:,1]
y_prob = [int(b) for b in y_test]

#Calculate brier score and print
brier_score = sum((y_pred_prob - y_prob)**2) / n_val
print("Brier Score:", brier_score)
# Out:
# Brier Score: 0.1931743389205207

# %%
# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
# Print the confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[4493  180]
#  [1818  285]]

# %%
#Add predicted outcome to the validation set
rec_val['y_pred'] = y_pred

#Split dataframes by race
rec_val_black = rec_val[rec_val['Race'] == 'BLACK']
rec_val_white = rec_val[rec_val['Race'] == 'WHITE']

#Calculate False Positive Rates by race
n_white_val = rec_val_white.shape[0]
n_black_val = rec_val_black.shape[0]

fpr_black = len(rec_val_black[(rec_val_black['Recidivism_Arrest_Year1'] == False) & (rec_val_black['y_pred'] == True)]) / n_black_val
fpr_white = len(rec_val_white[(rec_val_white['Recidivism_Arrest_Year1'] == False) & (rec_val_white['y_pred'] == True)]) / n_white_val

fairness_penalty = 1 - abs(fpr_black - fpr_white)

print("FPR Black:", fpr_black)
print("FPR White:", fpr_white)
# Out:
# FPR Black: 0.4487581384133108
# FPR White: 0.4419931532902244
# /var/folders/_g/vxz07v2s2pdb7dc0707cwt1c0000gn/T/ipykernel_19102/1529694348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_val['y_pred'] = y_pred

# %%
score = (1 - brier_score) * fairness_penalty
score
# Out:
# 0.7901415144213332
